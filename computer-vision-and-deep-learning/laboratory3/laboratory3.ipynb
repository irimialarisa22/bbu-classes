# %% [markdown]
# # Computer Vision and Deep Learning - Laboratory 3
#
# Starting from this session, we'll be diving into deep convolutional neural networks and we'll start using _tensorflow_ a popular machine learning library developed by Google.

# %%
import sys

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow.keras as keras
import cv2

color = 'red'
plt.rcParams['text.color'] = color
plt.rcParams['axes.labelcolor'] = color
plt.rcParams['xtick.color'] = color
plt.rcParams['ytick.color'] = color

print("done")
# Out:
# done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# download an image that we'll be using at this lab
# !wget https://www.researchgate.net/profile/Paul-Rodriguez-5/publication/265988128/figure/fig1/AS:459614656438273@1486592081799/Input-test-images-a-Cameraman-grayscale-b-grayscale-Lena-and-c-color-Lena-All_Q640.jpg -O cameraman.jpg
# Out:
# --2023-01-12 12:47:37--  https://www.researchgate.net/profile/Paul-Rodriguez-5/publication/265988128/figure/fig1/AS:459614656438273@1486592081799/Input-test-images-a-Cameraman-grayscale-b-grayscale-Lena-and-c-color-Lena-All_Q640.jpg
# Resolving www.researchgate.net (www.researchgate.net)... 104.17.32.105, 104.17.33.105, 2606:4700::6811:2069, ...
# Connecting to www.researchgate.net (www.researchgate.net)|104.17.32.105|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2023-01-12 12:47:38 ERROR 403: Forbidden.

# %%
# !wget "https://docs.google.com/uc?export=download&id=1zjltpYscUqnDSP6eUlU-gecadGXvQtTz" -O cute_cat.jpg
# Out:
# --2023-01-12 12:47:38--  https://docs.google.com/uc?export=download&id=1zjltpYscUqnDSP6eUlU-gecadGXvQtTz
# Resolving docs.google.com (docs.google.com)... 142.250.4.102, 142.250.4.101, 142.250.4.138, ...
# Connecting to docs.google.com (docs.google.com)|142.250.4.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-08-38-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/n99qpk2p539fggnisobblmg7qpeivldo/1673527650000/02075498819312407694/*/1zjltpYscUqnDSP6eUlU-gecadGXvQtTz?e=download&uuid=7351be10-4859-49e0-b013-dc9657c7af33 [following]
# Warning: wildcards not supported in HTTP.
# --2023-01-12 12:47:38--  https://doc-08-38-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/n99qpk2p539fggnisobblmg7qpeivldo/1673527650000/02075498819312407694/*/1zjltpYscUqnDSP6eUlU-gecadGXvQtTz?e=download&uuid=7351be10-4859-49e0-b013-dc9657c7af33
# Resolving doc-08-38-docs.googleusercontent.com (doc-08-38-docs.googleusercontent.com)... 74.125.24.132, 2404:6800:4003:c03::84
# Connecting to doc-08-38-docs.googleusercontent.com (doc-08-38-docs.googleusercontent.com)|74.125.24.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 143441 (140K) [image/jpeg]
# Saving to: ‘cute_cat.jpg’
#
# cute_cat.jpg        100%[===================>] 140.08K  --.-KB/s    in 0.001s
#
# 2023-01-12 12:47:39 (133 MB/s) - ‘cute_cat.jpg’ saved [143441/143441]

# %% [markdown]
# # Warm-up
#
#
# Let's start by implementing the basic blocks of a convolutional neural network: the convolutional and the pooling operations. Perhaps this would be the last "low-level" implementation that you'll do for this laboratory.
#
# ## Convolutions
#
# The convolutional layer is the main building block of a convolutional neural network. These layers contain a set of learnable filters, which will learn which features are relevant for the classification problem based on the training data.
# During the forward pass, each filter (which __must__ have the same depth as the input volume) is slided over the spatial dimensions of the input volume and we compute an element-wise multiplication between the filter weights and the region of interest in the input volume that lies beneath the filter.
#
# The hyperparameters of a convolutional layer are:
# - the filter size F (usually this is an odd value);
# - the padding amount which will be added to the input volume P;
# - the stride S (or the step used when sliding across the input volume);
# - the number of filters k; the depth of each filter must match the depth of the input volume;
#
# Given an input volume of shape  ($H_i$, $W_i$, $D$), the convolutional layer will produce an output of shape ($H_o$, $W_o$, $k$), where:
#
# \begin{equation}
# W_o = \frac{W_i - F + 2P}{S} + 1
# \end{equation}
#
# \begin{equation}
# H_o = \frac{H_i - F + 2P}{S} + 1
# \end{equation}
#
# <img src="https://lh6.googleusercontent.com/gZxwFH6mQ5tPjz6LzVbOaNeVuR1NC-BnuemIWO41qnn7r1PvP4qzwXRWC1OJgo2_PD08qaqJ2-VCF3q9laeK885IJwK-dHhpLDkvRZrx4vxrbLDTsKD2iZYM5SFRq4A6XTklk7_h"/>

# %%
def zero_pad(X, pad):
  """
  This function applies the zero padding operation on all the images in the array X
  :param X input array of images; this array has a of rank 4 (batch_size, height, width, channels)
  :param pad the amount of zeros to be added around around the spatial size of the images
  """
  # hint you might find the function numpy.pad useful for this purpose
  # keep in mind that you only need to pad the spatial dimensions (height and width)
  # TODO your code here
  X = np.pad(X, pad_width=((0, 0), (pad, pad), (pad, pad), (0, 0)))
  return X

# load the image using Pillow
img = Image.open('/content/drive/MyDrive/data/cameraman.jpg')
img = np.asarray(img)

# TODO your code here 
# pad and display the cameraman.jpg image 
# (if you are using matplotlib to display the image, use cmap='gray' in the imshow function)
img = np.stack([img], axis=2)
img = np.stack([img], axis=0)
print(img.shape)
img = zero_pad(img, 100)[0, :, :, 0]
print(img.shape)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
# Out:
# (1, 512, 512, 1)
# (712, 712)

# %%
def convolution(X, W, bias, pad, stride):
  """
  This function applied to convolution operation on the input X of shape (num_samples, iH, iW, iC)
  using the filters defined by the W (filter weights) and  (bias) parameters.

  :param X - input of shape (num_samples, iH, iW, iC)
  :param W - weights, numpy array of shape (fs, fs, iC, k), where fs is the filter size, 
    iC is the depth of the input volum and k is the number of filters applied on the image
  :param biases - numpy array of shape (1, 1, 1, k)
  :param pad - hyperparameter, the amount of padding to be applied
  :param stride - hyperparameter, the stride of the convolution
  """

  # 0. compute the size of the output activation map and initialize it with zeros

  num_samples = X.shape[0]
  iW = X.shape[2]
  iH = X.shape[1]
  f = W.shape[0]

  # TODO your code here
  # compute the output width (oW), height (oH) and number of channels (oC)
  oW = int((iW + 2*pad - f)/stride) + 1
  oH = int((iH + 2*pad - f)/stride) + 1
  oC = W.shape[3]
  # initialize the output activation map with zeros
  activation_map = np.zeros((num_samples, oH, oW, oC))
  # end TODO your code here

  # 1. pad the samples in the input 
  # TODO your code here, pad X using pad amount
  X_padded = zero_pad(X, pad)
  # end TODO your code here
  
  # go through each input sample
  for i in range(num_samples):                 
    # TODO: get the current sample from the input (use X_padded)
    X_i = X_padded[i]
    # end TODO your code here

    # loop over the spatial dimensions
    for y in range(oH):     
      # TODO your code here
      # compute the current ROI in the image on which the filter will be applied (y dimension)
      # tl_y - the y coordinate of the top left corner of the current region
      # br_y - the y coordinate of the bottom right corner of the current region
      tl_y = y*stride
      br_y = tl_y+f
      # end TODO your code here

      for x in range(oW):
        # TODO your code here       
        # compute the current ROI in the image on which the filter will be applied (x dimension)
        # tl_x - the x coordinate of the top left corner of the current region
        # br_x - the x coordinate of the bottom right corner of the current region
        tl_x = x*stride 
        br_x = tl_x+f
        # end TODO your code here
        
        for c in range(oC):               
            # select the current ROI on which the filter will be applied
            roi = X_padded[i, tl_y: br_y, tl_x: br_x, :]
            w = W[:, :, :, c]
            b = bias[:, :, :, c]
           
            # TODO your code here
            # apply the filter with the weights w and bias b on the current image roi
            # A. compute the elemetwise product between roi and the weights of the filters (np.multiply)
            a = np.multiply(roi, w)

            # B. sum across all the elements of a
            a = np.sum(a)

            # C. add the bias term
            a = np.add(a, b)

            # D. add the result in the appropriate position of the output activation map
            activation_map[i, y, x, c] = a
            # end TODO your code here
        assert(activation_map.shape == (num_samples, oH, oW, oC))
  return activation_map

np.random.seed(10)
# 100 samples of shape (13, 21, 4)
X = np.random.randn(100, 13, 21, 4)

# 8 filters (last dimension) of shape (3, 3)
W = np.random.randn(3, 3, 4, 8)
b = np.random.randn(1, 1, 1, 8)

am = convolution(X, W, b, pad=1, stride=2)
print("am's mean =\n", np.mean(am))
print("am[1, 2, 3] =\n", am[3,2,1])
# Out:
# am's mean =
#  -0.4284130223223714
# am[1, 2, 3] =
#  [ 1.78081902 -6.51813947 -4.35815226 -2.91158344  1.84016713 -3.72264278
#  -8.32761753 -3.22778695]

# %% [markdown]
# Expected output:
#
# am's mean =
#  -0.42841306
#
# am[1, 2, 3] =
#  [ 1.780819  -6.5181394 -4.3581524 -2.9115834  1.8401672 -3.722643
#  -8.327618  -3.227787 ]

# %% [markdown]
# Now let's analyse the effect of applying some well known filters used in image processing.
#
# ### Low pass filters
# Low pass filters are used to keep the low frequency information within an, while reducing the high frequency information. These filters are the basis of image smoothing.
#
# Two well known low pass filters are the _mean filter_ and the _Gaussian filter_.

# %%
# load the image using Pillow
image = Image.open('/content/drive/MyDrive/data/cameraman.jpg')
image = np.asarray(image)
image = np.expand_dims(image, axis=-1)

# X contains a single image sample
X = np.expand_dims(image, axis=0)

# %%
############################################################
# MEAN FILTER
############################################################

bias = np.asarray([0])
bias = bias.reshape((1, 1, 1, 1))

mean_filter_3 = np.ones(shape=(3, 3, 1, 1), dtype=np.float32)
mean_filter_3 = mean_filter_3/9.0

mean_filter_9 = np.ones(shape=(9, 9, 1, 1), dtype=np.float32)
mean_filter_9 = mean_filter_9/81.0

mean_3x3 = convolution(X, mean_filter_3, bias, pad=0, stride=1)
mean_9x9 = convolution(X, mean_filter_9, bias, pad=0, stride=1)

plt.figure(0)
plt.subplot(1, 2, 1)
plt.imshow(image[:, :, 0], cmap='gray')
plt.title('Original image')
plt.subplot(1, 2, 2)
plt.imshow(mean_3x3[0, :, :, 0], cmap='gray')
plt.title('Mean filter 3x3')

plt.figure(2)
plt.subplot(1, 2, 1)
plt.imshow(image[:, :, 0], cmap='gray')
plt.title('Original image')
plt.subplot(1, 2, 2)
plt.imshow(mean_9x9[0, :, :, 0], cmap='gray')
plt.title('Mean filter 9x9')


############################################################
# GAUSSIAN FILTER
############################################################

gaussian_filter = np.asarray(
    [[1, 2, 1],
     [2, 4, 2],
     [1, 2, 1]],
     dtype=np.float32
)
gaussian_filter = gaussian_filter.reshape(3, 3, 1, 1)
gaussian_filter = gaussian_filter/16.0

gaussian_smoothed = convolution(X, gaussian_filter, bias, pad=0, stride=1)

plt.figure(3)
plt.subplot(1, 2, 1)
plt.imshow(image[:, :, 0], cmap='gray')
plt.title('Original image')
plt.subplot(1, 2, 2)
plt.imshow(gaussian_smoothed[0,:,:,0], cmap='gray')
plt.title('Gaussian filtered')
# Out:
# Text(0.5, 1.0, 'Gaussian filtered')

# %% [markdown]
# __Optional__: Now load a color image and apply the mean filtering and Gaussian filtering on this color image.
# Not much changes at the call of the convolution operation, you just need to "play" with the convolutional kernels configurations.

# %%
# TODO your code here
image = cv2.imread('/content/drive/MyDrive/data/cute_cat.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (100, 100))
# X contains a single image sample
X = np.stack([image])
print(X.shape, np.mean(X))

bias = np.zeros((1, 1, 1, 3))

mean_filter_3 = np.ones(shape=(3, 3, 3, 3), dtype=np.float32)
mean_filter_3 /= 3*3*3

mean_filter_9 = np.ones(shape=(9, 9, 3, 3), dtype=np.float32)
mean_filter_9 /= 9*9*3

mean_3x3 = convolution(X, mean_filter_3, bias, pad=0, stride=1)[0].astype(int)
print(f"Done 3x3 {mean_3x3.shape} {np.mean(mean_3x3)} {np.max(mean_3x3)}")
mean_9x9 = convolution(X, mean_filter_9, bias, pad=0, stride=1)[0].astype(int)
print(f"Done 9x9 {mean_9x9.shape} {np.mean(mean_9x9)} {np.max(mean_3x3)}")

plt.figure(0)
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title('Original image')
plt.subplot(1, 2, 2)
plt.imshow(mean_3x3)
plt.title('mean filter 3x3')

plt.figure(2)
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title('Original image')
plt.subplot(1, 2, 2)
plt.imshow(mean_9x9)
plt.title('mean filter 9x9')

gaussian_filter = np.asarray(
    [[1, 2, 1],
     [2, 4, 2],
     [1, 2, 1]],
    dtype=np.float32
)
gaussian_filter = np.stack([gaussian_filter]*3, -1)
gaussian_filter = np.stack([gaussian_filter]*3, -1)
gaussian_filter /= 16.0 * 3
print(f"Gaussian filter shape {gaussian_filter.shape}")

gaussian_smoothed = convolution(X, gaussian_filter, bias, pad=0, stride=1)[0].astype(int)
print(f"Done gaussian {gaussian_smoothed.shape}")

plt.figure(3)
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title('Original image')
plt.subplot(1, 2, 2)
plt.imshow(gaussian_smoothed)
plt.title('Gaussian filtered')
# Out:
# (1, 100, 100, 3) 111.7644
# Done 3x3 (98, 98, 3) 111.03519366930446 241
# Done 9x9 (92, 92, 3) 110.10822306238185 241
# Gaussian filter shape (3, 3, 3, 3)
# Done gaussian (98, 98, 3)
# Text(0.5, 1.0, 'Gaussian filtered')

# %% [markdown]
# ### High pass filters
#
# On the other hand, high pass filters are used to highlight the high frequency information in an image (edges, abrupt changes in intensities).
#
# One of the most commonly used high pass filters is the Sobel kernel (depicted below). These filters can be seen as discrete differentiation operators, and they compute an approximation of the gradient (on the horizontal or vertical direction) of the image intensity function.
#
# <img src="https://i.ytimg.com/vi/W7OpxFbrD84/maxresdefault.jpg" width=300px/>

# %%
image = cv2.imread('/content/drive/MyDrive/data/cameraman.jpg', 0)
image = np.asarray(image)
image = np.expand_dims(image, axis=-1)

# X contains a single image sample
X = np.expand_dims(image, axis=0)

sobel_horiz = np.asarray([[-1, 0, 1],
                          [-2, 0, 2], 
                          [-1, 0, 1]])

sobel_vert = sobel_horiz.T

sobel_horiz = np.reshape(sobel_horiz, (3, 3, 1, 1))
sobel_vert = np.reshape(sobel_vert, (3, 3, 1, 1))

sobel_x = convolution(X, sobel_horiz, bias, 0, 1)
sobel_y = convolution(X, sobel_vert, bias, 0, 1)


plt.subplot(1, 3, 1)
plt.imshow(image[:, :, 0], cmap='gray')
plt.title('Original image')
plt.subplot(1, 3, 2)
plt.imshow(np.abs(sobel_x[0,:,:,0])/np.abs(np.max(sobel_x[0,:,:,0]))*255, cmap='gray')
plt.title('Sobel X')
plt.subplot(1, 3, 3)
plt.imshow(np.abs(sobel_y[0,:,:,0])/np.abs(np.max(sobel_y[0,:,:,0]))*255, cmap='gray')
plt.title('Sobel Y')
plt.tight_layout()

# %% [markdown]
# ## Pooling
#
# The pooling layer is used to reduce the spatial dimension of the activation maps, and thus the computational burden. It has no learnable parameters and it operates individually across each input channel and resizes it spatially.
#
# The two most common types of pooling are max pooling and average pooling.
#
#
# The hyperparameters of a pooling layer are:
# - the filter size F (usually this is an odd value);
# - the stride S (or the step used when sliding across the input volume);
#
# Given an input volume of shape  ($H_i$, $W_i$, $D$), the convolutional layer will produce an output of shape ($H_o$, $W_o$, $D$), where:
#
# \begin{equation}
# W_o = \frac{W_i - F}{S} + 1
# \end{equation}
#
# \begin{equation}
# H_o = \frac{H_i - F}{S} + 1
# \end{equation}
#
# An illustration of the pooling operation is depicted in the image below:
#
# ![picture](https://www.researchgate.net/profile/Alla-Eddine-Guissous/publication/337336341/figure/fig15/AS:855841334898691@1581059883782/Example-for-the-max-pooling-and-the-average-pooling-with-a-filter-size-of-22-and-a.jpg)

# %%
def pooling(X, filter_size, stride, type):
    """
    Implements the pooling operation

    :param X - input volume of shape (num_samples, H, W, C)
    :param filter_size - the size of the pooling
    :param stride - the stride of the pooling operation
    :param type - can be 'max' or 'avg'; the type of the pooling operation to apply

    Returns the output of the pooling operation.
    """
    # TODO your code here implement the pooling operation
    # you can ispire yourself from the convolution implementation on how to organize your code
    pool = {
        "max": np.max,
        "avg": np.average
    }

    num_samples = X.shape[0]
    iW = X.shape[2]
    iH = X.shape[1]

    oW = int((iW - filter_size)/stride) + 1
    oH = int((iH - filter_size)/stride) + 1
    oC = X.shape[3]

    activation_map = np.zeros((num_samples, oH, oW, oC))
    for i in range(num_samples):
        for y in range(oH):
            tl_y = y*stride
            br_y = tl_y+filter_size
            for x in range(oW):
                tl_x = x*stride
                br_x = tl_x+filter_size
                for c in range(oC):
                    roi = X[i, tl_y: br_y, tl_x: br_x, c]
                    activation_map[i, y, x, c] = pool[type](roi)
    assert(activation_map.shape == (num_samples, oH, oW, oC))
    return activation_map


a = np.array([
    [2, 3, 2, 0],
    [5,-2, 2, 8],
    [-1, -6, 7, 3],
    [-4, -5, 4, 2]
])
a = np.stack([a])
a = np.stack([a], -1)
mx = pooling(a, 2, 2, "max")[0]
avg = pooling(a, 2, 2, "avg")[0]
print(mx)
print(avg)


# TODO your code here
# apply the pooling operation on a grayscale image and on a color image
# try different values for the stride and filter size. What do you observe?
#       larger filter size and stride blur the image more
#       max pooling brightens the image, whereas the avg pooling is closer to the original image
class Test:
    count=0
    def __init__(self, gray, colored, imgGray, imgColored):
        self.imgGray = imgGray
        self.img = imgColored
        self.aux(gray)
        self.aux(colored)

    def aux(self, X):
        test = self.test_pool if X.shape[3] == 3 else self.test_pool_gray
        test(X, 2, 2)
        test(X, 4, 4)
        test(X, 16, 16)
        test(X, 32, 32)

    def test_pool_gray(self, X, filter_size, stride):
        mx = pooling(X, filter_size, stride, "max").astype(int)
        avg = pooling(X, filter_size, stride, "avg").astype(int)
        print(f"Max: {mx.shape} Avg: {avg.shape}")
        plt.figure(self.count)
        plt.subplot(1, 3, 1)
        plt.imshow(self.imgGray[:, :, 0], cmap='gray')
        plt.title(f"Original image {filter_size}x{filter_size} s: {stride}")
        plt.subplot(1, 3, 2)
        plt.imshow(mx[0, :, :, 0], cmap='gray')
        plt.title(f"max")
        plt.subplot(1, 3, 3)
        plt.imshow(avg[0, :, :, 0], cmap='gray')
        plt.title(f"avg")
        plt.tight_layout()
        self.count+=1

    def test_pool(self, X, filter_size, stride):
        mx = pooling(X, filter_size, stride, "max")[0].astype(int)
        avg = pooling(X, filter_size, stride, "avg")[0].astype(int)
        # print(f"Max: {mx.shape} Avg: {avg.shape}")
        plt.figure(self.count)
        plt.subplot(1, 3, 1)
        plt.imshow(self.img)
        plt.title(f"Original image {filter_size}x{filter_size} s: {stride}")
        plt.subplot(1, 3, 2)
        plt.imshow(mx)
        plt.title(f"max ")
        plt.subplot(1, 3, 3)
        plt.imshow(avg)
        plt.title(f"avg")
        plt.tight_layout()
        self.count+=1

imageGray = Image.open('/content/drive/MyDrive/data/cameraman.jpg')
imageGray = np.asarray(imageGray)
imageGray = np.expand_dims(imageGray, axis=-1)

# X contains a single image sample
gray = np.expand_dims(imageGray, axis=0)

image = cv2.imread('/content/drive/MyDrive/data/cute_cat.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (512, 512))
# X contains a single image sample
colored = np.stack([image])
print(f"Gray shape: {gray.shape}, colored: {colored.shape}")
Test(gray, colored, imageGray, image)
# Out:
# [[[ 5.]
#   [ 8.]]
#
#  [[-1.]
#   [ 7.]]]
# [[[ 2.]
#   [ 3.]]
#
#  [[-4.]
#   [ 4.]]]
# Gray shape: (1, 512, 512, 1), colored: (1, 512, 512, 3)
# Max: (1, 256, 256, 1) Avg: (1, 256, 256, 1)
# Max: (1, 128, 128, 1) Avg: (1, 128, 128, 1)
# Max: (1, 32, 32, 1) Avg: (1, 32, 32, 1)
# Max: (1, 16, 16, 1) Avg: (1, 16, 16, 1)

# %% [markdown]
# # Hello, _tensorflow_!
#
# Follow [this tutorial](https://www.tensorflow.org/tutorials/images/cnn) to build your first convolutional neural network using a sequential model in a few lines of code.

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import ssl
import os
print("done")
# Out:
# done

# %%
ssl._create_default_https_context = ssl._create_unverified_context
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0
print("done")
# Out:
# done

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %%
def plot_history(history):
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0, 1])
    plt.legend(loc='upper right')

    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label = 'val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    #plt.ylim([0, 1])
    plt.legend(loc='upper right')

# %%
from tensorflow.python.client import device_lib
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print(device_lib.list_local_devices())
print("done")
# Out:
# Num GPUs Available:  1
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8334568528602416128
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14415560704
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1012828074568053417
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]
# done

# %%
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), padding="same", activation='relu', input_shape=(32, 32, 3)))
model.add(layers.Conv2D(32, (3, 3), padding="same", activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), padding="same", activation='relu'))
model.add(layers.Conv2D(32, (3, 3), padding="same", activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), padding="same", activation='relu'))
model.add(layers.Conv2D(64, (3, 3), padding="same", activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))
model.summary()

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history =  model.fit(train_images, train_labels, epochs=15, batch_size=256,
                    validation_data=(test_images, test_labels),
                     callbacks=[callback]
                    )

print("History of the basic version")
plot_history(history)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_30 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_10 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 16, 16, 32)        9248
#
#  conv2d_33 (Conv2D)          (None, 16, 16, 32)        9248
#
#  max_pooling2d_11 (MaxPoolin  (None, 8, 8, 32)         0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 8, 8, 64)          18496
#
#  conv2d_35 (Conv2D)          (None, 8, 8, 64)          36928
#
#  flatten_5 (Flatten)         (None, 4096)              0
#
#  dense_10 (Dense)            (None, 64)                262208
#
#  dense_11 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 346,922
# Trainable params: 346,922
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 196/196 [==============================] - 5s 21ms/step - loss: 1.6686 - accuracy: 0.3930 - val_loss: 1.3765 - val_accuracy: 0.5037 - lr: 0.0010
# Epoch 2/15
# 196/196 [==============================] - 4s 19ms/step - loss: 1.2640 - accuracy: 0.5469 - val_loss: 1.1470 - val_accuracy: 0.5854 - lr: 0.0010
# Epoch 3/15
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0555 - accuracy: 0.6253 - val_loss: 0.9807 - val_accuracy: 0.6557 - lr: 0.0010
# Epoch 4/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9164 - accuracy: 0.6775 - val_loss: 0.9218 - val_accuracy: 0.6802 - lr: 0.0010
# Epoch 5/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.8113 - accuracy: 0.7182 - val_loss: 0.9148 - val_accuracy: 0.6829 - lr: 0.0010
# Epoch 6/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.7398 - accuracy: 0.7429 - val_loss: 0.8064 - val_accuracy: 0.7264 - lr: 0.0010
# Epoch 7/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.6665 - accuracy: 0.7673 - val_loss: 0.7619 - val_accuracy: 0.7330 - lr: 0.0010
# Epoch 8/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.6116 - accuracy: 0.7878 - val_loss: 0.7592 - val_accuracy: 0.7437 - lr: 0.0010
# Epoch 9/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.5570 - accuracy: 0.8048 - val_loss: 0.7678 - val_accuracy: 0.7438 - lr: 0.0010
# Epoch 10/15
# 196/196 [==============================] - 4s 19ms/step - loss: 0.5108 - accuracy: 0.8207 - val_loss: 0.7817 - val_accuracy: 0.7461 - lr: 0.0010
# Epoch 11/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.4449 - accuracy: 0.8444 - val_loss: 0.7780 - val_accuracy: 0.7477 - lr: 9.0484e-04
# Epoch 12/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.3872 - accuracy: 0.8646 - val_loss: 0.8076 - val_accuracy: 0.7564 - lr: 8.1873e-04
# Epoch 13/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.3340 - accuracy: 0.8832 - val_loss: 0.8201 - val_accuracy: 0.7549 - lr: 7.4082e-04
# Epoch 14/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.2806 - accuracy: 0.9023 - val_loss: 0.8730 - val_accuracy: 0.7516 - lr: 6.7032e-04
# Epoch 15/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.2336 - accuracy: 0.9190 - val_loss: 0.9102 - val_accuracy: 0.7486 - lr: 6.0653e-04
# History of the basic version

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print(test_acc)
model.save(f"./weights_v2/test_acc_{str(test_acc)[:5]}")
# Out:
# 313/313 - 1s - loss: 0.9102 - accuracy: 0.7486 - 930ms/epoch - 3ms/step
# 0.7486000061035156
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.

# %%
new_model = tf.keras.models.load_model('/content/drive/MyDrive/weights_v2/test_acc_0.759')

# Check its architecture
new_model.summary()

test_loss, test_acc = new_model.evaluate(test_images,  test_labels, verbose=2)
print(test_acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 32)        9248
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 64)          18496
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 64)          36928
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 64)                262208
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 346,922
# Trainable params: 346,922
# Non-trainable params: 0
# _________________________________________________________________
# 313/313 - 1s - loss: 0.8820 - accuracy: 0.7600 - 1000ms/epoch - 3ms/step
# 0.7599999904632568

# %%
print("Added He initializer")
initializer = tf.keras.initializers.HeNormal()

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3),
                        kernel_initializer=initializer,
                        padding="same", activation='relu', input_shape=(32, 32, 3)))
model.add(layers.Conv2D(32, (3, 3),
                        kernel_initializer=initializer,
                        padding="same", activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3),
                        kernel_initializer=initializer,
                        padding="same", activation='relu'))
model.add(layers.Conv2D(32, (3, 3),
                        kernel_initializer=initializer,
                        padding="same", activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3),
                        kernel_initializer=initializer,
                        padding="same", activation='relu'))
model.add(layers.Conv2D(64, (3, 3),
                        kernel_initializer=initializer,
                        padding="same", activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64,
                       kernel_initializer=initializer,
                       activation='relu'))
model.add(layers.Dense(10))

model.summary()

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history =  model.fit(train_images, train_labels, epochs=15, batch_size=256,
                     validation_data=(test_images, test_labels),
                     callbacks=[callback]
                     )

plot_history(history)
# Out:
# Added He initializer
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_37 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_12 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 16, 16, 32)        9248
#
#  conv2d_39 (Conv2D)          (None, 16, 16, 32)        9248
#
#  max_pooling2d_13 (MaxPoolin  (None, 8, 8, 32)         0
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 8, 8, 64)          18496
#
#  conv2d_41 (Conv2D)          (None, 8, 8, 64)          36928
#
#  flatten_6 (Flatten)         (None, 4096)              0
#
#  dense_12 (Dense)            (None, 64)                262208
#
#  dense_13 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 346,922
# Trainable params: 346,922
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 196/196 [==============================] - 4s 20ms/step - loss: 1.5579 - accuracy: 0.4380 - val_loss: 1.2965 - val_accuracy: 0.5289 - lr: 0.0010
# Epoch 2/15
# 196/196 [==============================] - 4s 18ms/step - loss: 1.1424 - accuracy: 0.5978 - val_loss: 1.1219 - val_accuracy: 0.6092 - lr: 0.0010
# Epoch 3/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9406 - accuracy: 0.6703 - val_loss: 0.9462 - val_accuracy: 0.6713 - lr: 0.0010
# Epoch 4/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.8007 - accuracy: 0.7219 - val_loss: 0.8804 - val_accuracy: 0.6960 - lr: 0.0010
# Epoch 5/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.7041 - accuracy: 0.7544 - val_loss: 0.8744 - val_accuracy: 0.7010 - lr: 0.0010
# Epoch 6/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.6179 - accuracy: 0.7844 - val_loss: 0.8362 - val_accuracy: 0.7221 - lr: 0.0010
# Epoch 7/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.5477 - accuracy: 0.8090 - val_loss: 0.8111 - val_accuracy: 0.7308 - lr: 0.0010
# Epoch 8/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.4793 - accuracy: 0.8327 - val_loss: 0.8580 - val_accuracy: 0.7246 - lr: 0.0010
# Epoch 9/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.4206 - accuracy: 0.8537 - val_loss: 0.8665 - val_accuracy: 0.7259 - lr: 0.0010
# Epoch 10/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.3635 - accuracy: 0.8705 - val_loss: 0.9529 - val_accuracy: 0.7134 - lr: 0.0010
# Epoch 11/15
# 196/196 [==============================] - 4s 19ms/step - loss: 0.2966 - accuracy: 0.8965 - val_loss: 1.0021 - val_accuracy: 0.7173 - lr: 9.0484e-04
# Epoch 12/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.2337 - accuracy: 0.9180 - val_loss: 1.0306 - val_accuracy: 0.7293 - lr: 8.1873e-04
# Epoch 13/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.1788 - accuracy: 0.9380 - val_loss: 1.1256 - val_accuracy: 0.7281 - lr: 7.4082e-04
# Epoch 14/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.1303 - accuracy: 0.9561 - val_loss: 1.2378 - val_accuracy: 0.7305 - lr: 6.7032e-04
# Epoch 15/15
# 196/196 [==============================] - 4s 18ms/step - loss: 0.0982 - accuracy: 0.9668 - val_loss: 1.3310 - val_accuracy: 0.7312 - lr: 6.0653e-04

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print(test_acc)
model.save(f"./weights_v2/test_acc_{str(test_acc)[:4]}_with_he_initializer")
# Out:
# 313/313 - 1s - loss: 1.3310 - accuracy: 0.7312 - 875ms/epoch - 3ms/step
# 0.7311999797821045
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.

# %%
print("Added regularization")
initializer = tf.keras.initializers.HeNormal()
regularizer = tf.keras.regularizers.l1_l2(l1=1e-5, l2=1e-4)
#regularizer = tf.keras.regularizers.l2(l2=1e-3)

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3),
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer,
                        activity_regularizer=regularizer,
                        padding="same", activation='relu', input_shape=(32, 32, 3)))
model.add(layers.Conv2D(32, (3, 3),
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer,
                        activity_regularizer=regularizer,
                        padding="same", activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3),
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer,
                        activity_regularizer=regularizer,
                        padding="same", activation='relu'))
model.add(layers.Conv2D(32, (3, 3),
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer,
                        activity_regularizer=regularizer,
                        padding="same", activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3),
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer,
                        activity_regularizer=regularizer,
                        padding="same", activation='relu'))
model.add(layers.Conv2D(64, (3, 3),
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer,
                        activity_regularizer=regularizer,
                        padding="same", activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64,
                       kernel_initializer=initializer,
                       kernel_regularizer=regularizer,
                       bias_regularizer=regularizer,
                       activity_regularizer=regularizer,
                       activation='relu'))
model.add(layers.Dense(10))

model.summary()

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history =  model.fit(train_images, train_labels, epochs=15, batch_size=256,
                     validation_data=(test_images, test_labels),
                     callbacks=[callback]
                     )

plot_history(history)
# Out:
# Added regularization
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_42 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_43 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_14 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 16, 16, 32)        9248
#
#  conv2d_45 (Conv2D)          (None, 16, 16, 32)        9248
#
#  max_pooling2d_15 (MaxPoolin  (None, 8, 8, 32)         0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 8, 8, 64)          18496
#
#  conv2d_47 (Conv2D)          (None, 8, 8, 64)          36928
#
#  flatten_7 (Flatten)         (None, 4096)              0
#
#  dense_14 (Dense)            (None, 64)                262208
#
#  dense_15 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 346,922
# Trainable params: 346,922
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 196/196 [==============================] - 8s 33ms/step - loss: 2.0212 - accuracy: 0.3841 - val_loss: 1.6275 - val_accuracy: 0.4929 - lr: 0.0010
# Epoch 2/15
# 196/196 [==============================] - 6s 30ms/step - loss: 1.4533 - accuracy: 0.5487 - val_loss: 1.3555 - val_accuracy: 0.5818 - lr: 0.0010
# Epoch 3/15
# 196/196 [==============================] - 6s 30ms/step - loss: 1.2501 - accuracy: 0.6264 - val_loss: 1.2422 - val_accuracy: 0.6286 - lr: 0.0010
# Epoch 4/15
# 196/196 [==============================] - 6s 31ms/step - loss: 1.1277 - accuracy: 0.6718 - val_loss: 1.1068 - val_accuracy: 0.6824 - lr: 0.0010
# Epoch 5/15
# 196/196 [==============================] - 6s 31ms/step - loss: 1.0420 - accuracy: 0.7043 - val_loss: 1.0517 - val_accuracy: 0.7032 - lr: 0.0010
# Epoch 6/15
# 196/196 [==============================] - 6s 32ms/step - loss: 0.9796 - accuracy: 0.7297 - val_loss: 0.9999 - val_accuracy: 0.7234 - lr: 0.0010
# Epoch 7/15
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9242 - accuracy: 0.7505 - val_loss: 0.9904 - val_accuracy: 0.7236 - lr: 0.0010
# Epoch 8/15
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8790 - accuracy: 0.7668 - val_loss: 0.9414 - val_accuracy: 0.7474 - lr: 0.0010
# Epoch 9/15
# 196/196 [==============================] - 6s 30ms/step - loss: 0.8360 - accuracy: 0.7849 - val_loss: 0.9734 - val_accuracy: 0.7360 - lr: 0.0010
# Epoch 10/15
# 196/196 [==============================] - 6s 30ms/step - loss: 0.8000 - accuracy: 0.7985 - val_loss: 0.9240 - val_accuracy: 0.7582 - lr: 0.0010
# Epoch 11/15
# 196/196 [==============================] - 6s 32ms/step - loss: 0.7628 - accuracy: 0.8123 - val_loss: 0.9460 - val_accuracy: 0.7514 - lr: 9.0484e-04
# Epoch 12/15
# 196/196 [==============================] - 6s 31ms/step - loss: 0.7247 - accuracy: 0.8283 - val_loss: 0.9010 - val_accuracy: 0.7655 - lr: 8.1873e-04
# Epoch 13/15
# 196/196 [==============================] - 6s 31ms/step - loss: 0.6903 - accuracy: 0.8419 - val_loss: 0.8773 - val_accuracy: 0.7745 - lr: 7.4082e-04
# Epoch 14/15
# 196/196 [==============================] - 6s 31ms/step - loss: 0.6569 - accuracy: 0.8559 - val_loss: 0.8663 - val_accuracy: 0.7789 - lr: 6.7032e-04
# Epoch 15/15
# 196/196 [==============================] - 6s 31ms/step - loss: 0.6346 - accuracy: 0.8627 - val_loss: 0.9061 - val_accuracy: 0.7691 - lr: 6.0653e-04

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
model.save(f"./weights_v2/test_acc_{str(test_acc)[:5]}_with_regularization")
# Out:
# 313/313 - 2s - loss: 0.9061 - accuracy: 0.7691 - 2s/epoch - 5ms/step
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.

# %%
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

print("Added dropout")
initializer = tf.keras.initializers.HeNormal()
#regularizer = tf.keras.regularizers.l1_l2(l1=1e-7, l2=1e-6)
#regularizer = tf.keras.regularizers.l2(l2=2e-4)
regularizer = tf.keras.regularizers.l1_l2(l1=1e-6, l2=2e-4)

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3),
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer,
                        activity_regularizer=regularizer,
                        padding="same", activation='relu', input_shape=(32, 32, 3)))
model.add(layers.Conv2D(32, (3, 3),
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer,
                        activity_regularizer=regularizer,
                        padding="same", activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3),
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer,
                        activity_regularizer=regularizer,
                        padding="same", activation='relu'))
model.add(layers.Conv2D(32, (3, 3),
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer,
                        activity_regularizer=regularizer,
                        padding="same", activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3),
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer,
                        activity_regularizer=regularizer,
                        padding="same", activation='relu'))
model.add(layers.Conv2D(64, (3, 3),
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer,
                        activity_regularizer=regularizer,
                        padding="same", activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64,
                       kernel_initializer=initializer,
                       kernel_regularizer=regularizer,
                       bias_regularizer=regularizer,
                       activity_regularizer=regularizer,
                       activation='relu'))
model.add(layers.Dropout(.5))
model.add(layers.Dense(10))

model.summary()

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history =  model.fit(train_images, train_labels, epochs=20, batch_size=256,
                     validation_data=(test_images, test_labels),
                     callbacks=[callback]
                     )

plot_history(history)
# Out:
# Added dropout
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_48 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_49 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_16 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_50 (Conv2D)          (None, 16, 16, 32)        9248
#
#  conv2d_51 (Conv2D)          (None, 16, 16, 32)        9248
#
#  max_pooling2d_17 (MaxPoolin  (None, 8, 8, 32)         0
#  g2D)
#
#  conv2d_52 (Conv2D)          (None, 8, 8, 64)          18496
#
#  conv2d_53 (Conv2D)          (None, 8, 8, 64)          36928
#
#  flatten_8 (Flatten)         (None, 4096)              0
#
#  dense_16 (Dense)            (None, 64)                262208
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_17 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 346,922
# Trainable params: 346,922
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 196/196 [==============================] - 9s 33ms/step - loss: 2.6249 - accuracy: 0.2435 - val_loss: 1.8234 - val_accuracy: 0.4173 - lr: 0.0010
# Epoch 2/20
# 196/196 [==============================] - 6s 30ms/step - loss: 1.8200 - accuracy: 0.3808 - val_loss: 1.5827 - val_accuracy: 0.4752 - lr: 0.0010
# Epoch 3/20
# 196/196 [==============================] - 6s 30ms/step - loss: 1.6393 - accuracy: 0.4515 - val_loss: 1.4243 - val_accuracy: 0.5422 - lr: 0.0010
# Epoch 4/20
# 196/196 [==============================] - 6s 31ms/step - loss: 1.5171 - accuracy: 0.5056 - val_loss: 1.3253 - val_accuracy: 0.5875 - lr: 0.0010
# Epoch 5/20
# 196/196 [==============================] - 6s 31ms/step - loss: 1.4081 - accuracy: 0.5477 - val_loss: 1.3050 - val_accuracy: 0.5743 - lr: 0.0010
# Epoch 6/20
# 196/196 [==============================] - 6s 33ms/step - loss: 1.3365 - accuracy: 0.5805 - val_loss: 1.1768 - val_accuracy: 0.6392 - lr: 0.0010
# Epoch 7/20
# 196/196 [==============================] - 6s 31ms/step - loss: 1.2545 - accuracy: 0.6146 - val_loss: 1.1206 - val_accuracy: 0.6552 - lr: 0.0010
# Epoch 8/20
# 196/196 [==============================] - 6s 31ms/step - loss: 1.1966 - accuracy: 0.6415 - val_loss: 1.1449 - val_accuracy: 0.6600 - lr: 0.0010
# Epoch 9/20
# 196/196 [==============================] - 6s 31ms/step - loss: 1.1395 - accuracy: 0.6638 - val_loss: 1.0196 - val_accuracy: 0.7022 - lr: 0.0010
# Epoch 10/20
# 196/196 [==============================] - 6s 31ms/step - loss: 1.0897 - accuracy: 0.6854 - val_loss: 1.0673 - val_accuracy: 0.6867 - lr: 0.0010
# Epoch 11/20
# 196/196 [==============================] - 6s 31ms/step - loss: 1.0344 - accuracy: 0.7060 - val_loss: 0.9550 - val_accuracy: 0.7309 - lr: 9.0484e-04
# Epoch 12/20
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9811 - accuracy: 0.7266 - val_loss: 0.9298 - val_accuracy: 0.7377 - lr: 8.1873e-04
# Epoch 13/20
# 196/196 [==============================] - 6s 30ms/step - loss: 0.9426 - accuracy: 0.7402 - val_loss: 0.9116 - val_accuracy: 0.7481 - lr: 7.4082e-04
# Epoch 14/20
# 196/196 [==============================] - 6s 30ms/step - loss: 0.9069 - accuracy: 0.7530 - val_loss: 0.9075 - val_accuracy: 0.7518 - lr: 6.7032e-04
# Epoch 15/20
# 196/196 [==============================] - 6s 30ms/step - loss: 0.8784 - accuracy: 0.7662 - val_loss: 0.8950 - val_accuracy: 0.7531 - lr: 6.0653e-04
# Epoch 16/20
# 196/196 [==============================] - 6s 30ms/step - loss: 0.8467 - accuracy: 0.7749 - val_loss: 0.8738 - val_accuracy: 0.7629 - lr: 5.4881e-04
# Epoch 17/20
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8266 - accuracy: 0.7835 - val_loss: 0.8578 - val_accuracy: 0.7678 - lr: 4.9659e-04
# Epoch 18/20
# 196/196 [==============================] - 6s 30ms/step - loss: 0.8032 - accuracy: 0.7938 - val_loss: 0.8578 - val_accuracy: 0.7683 - lr: 4.4933e-04
# Epoch 19/20
# 196/196 [==============================] - 6s 31ms/step - loss: 0.7858 - accuracy: 0.7976 - val_loss: 0.8451 - val_accuracy: 0.7731 - lr: 4.0657e-04
# Epoch 20/20
# 196/196 [==============================] - 6s 31ms/step - loss: 0.7626 - accuracy: 0.8070 - val_loss: 0.8502 - val_accuracy: 0.7735 - lr: 3.6788e-04

# %%
print("Further train")

history =  model.fit(train_images, train_labels, epochs=10, batch_size=256,
                     validation_data=(test_images, test_labels),
                     callbacks=[callback]
                     )

plot_history(history)
# Out:
# Further train
# Epoch 1/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.7511 - accuracy: 0.8104 - val_loss: 0.8561 - val_accuracy: 0.7680 - lr: 3.6788e-04
# Epoch 2/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.7411 - accuracy: 0.8142 - val_loss: 0.8374 - val_accuracy: 0.7778 - lr: 3.6788e-04
# Epoch 3/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.7313 - accuracy: 0.8175 - val_loss: 0.8560 - val_accuracy: 0.7718 - lr: 3.6788e-04
# Epoch 4/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.7188 - accuracy: 0.8221 - val_loss: 0.8316 - val_accuracy: 0.7824 - lr: 3.6788e-04
# Epoch 5/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.7071 - accuracy: 0.8269 - val_loss: 0.8281 - val_accuracy: 0.7848 - lr: 3.6788e-04
# Epoch 6/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.6972 - accuracy: 0.8316 - val_loss: 0.8373 - val_accuracy: 0.7846 - lr: 3.6788e-04
# Epoch 7/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.6856 - accuracy: 0.8351 - val_loss: 0.8312 - val_accuracy: 0.7802 - lr: 3.6788e-04
# Epoch 8/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.6761 - accuracy: 0.8375 - val_loss: 0.8367 - val_accuracy: 0.7817 - lr: 3.6788e-04
# Epoch 9/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.6622 - accuracy: 0.8433 - val_loss: 0.8285 - val_accuracy: 0.7851 - lr: 3.6788e-04
# Epoch 10/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.6540 - accuracy: 0.8462 - val_loss: 0.8350 - val_accuracy: 0.7837 - lr: 3.6788e-04

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

model.save(f"./weights_v2/test_acc_{str(test_acc)[:5] }_with_dropout")
# Out:
# 313/313 - 1s - loss: 0.8350 - accuracy: 0.7837 - 1s/epoch - 5ms/step
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.

# %%
from tensorflow.python.keras import backend as K

def clip(x, left, right):
    return max(left, min(x, right))

def cutout(x, cropSize):
    cut_x = x
    shape = x.get_shape()

    mask = np.ones(shape)
    x_coord = np.random.randint(0, shape[0])
    y_coord = np.random.randint(0, shape[1])
    tl_x = clip(x_coord-cropSize, 0,shape[0])
    tl_y = clip(y_coord-cropSize, 0, shape[1])
    br_x = clip(x_coord+cropSize, 0, shape[0])
    br_y = clip(y_coord+cropSize, 0,  shape[1])
    mask[tl_x:br_x, tl_y:br_y, :] = np.zeros((br_x-tl_x, br_y-tl_y, shape[2]))

    cut_x = tf.where(tf.convert_to_tensor(mask, dtype=tf.bool), cut_x, 0)
    return cut_x

class Cutout(layers.Layer):
    def __init__(self, cropSize, **kwargs):
        super().__init__(**kwargs)
        self.cropSize = cropSize # cropped region will be cropSize*2+1

    def call(self, x, training=None):
        if not training:
            return x
        return tf.map_fn(lambda elem: cutout(elem, self.cropSize), x)

class CutoutModel(tf.keras.Model):
    def __init__(self, cropSize, input_shape):
        super(CutoutModel, self).__init__(name='')
        self.cutout = Cutout(cropSize, input_shape= input_shape)

    def call(self, input_tensor, training=False):
        x = input_tensor
        if training:
            x = self.cutout(input_tensor)
        return x

# %%
image = cv2.imread('/content/drive/MyDrive/data/cute_cat.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (500, 500))
# X contains a single image sample
X = np.stack([image]*32)
print(X.shape)
cut_X = Cutout(100)(tf.convert_to_tensor(X))

plt.subplot(1,3,1)
plt.imshow(image)
plt.subplot(1,3,2)
plt.imshow(cut_X[0])
plt.subplot(1,3,3)
plt.imshow(cut_X[1])
# Out:
# (32, 500, 500, 3)

# %%
print("Added cutout...")

def train_coutout(cutoutValue):
    print(f"Cutout value: {cutoutValue}")
    initializer = tf.keras.initializers.HeNormal()
    #regularizer = tf.keras.regularizers.l1_l2(l1=1e-7, l2=1e-6)
    #regularizer = tf.keras.regularizers.l2(l2=1e-4)
    #regularizer = tf.keras.regularizers.l1_l2(l1=1e-6, l2=1e-5)

    regularizer = tf.keras.regularizers.l1_l2(l1=1e-6, l2=2e-4)

    model = models.Sequential()
    model.add(Cutout(cutoutValue))
    model.add(layers.Conv2D(32, (3, 3),
                            kernel_initializer=initializer,
                            kernel_regularizer=regularizer,
                            bias_regularizer=regularizer,
                            activity_regularizer=regularizer,
                            padding="same", activation='relu', input_shape=(32, 32, 3)))
    model.add(layers.Conv2D(32, (3, 3),
                            kernel_initializer=initializer,
                            kernel_regularizer=regularizer,
                            bias_regularizer=regularizer,
                            activity_regularizer=regularizer,
                            padding="same", activation='relu', input_shape=(32, 32, 3)))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(32, (3, 3),
                            kernel_initializer=initializer,
                            kernel_regularizer=regularizer,
                            bias_regularizer=regularizer,
                            activity_regularizer=regularizer,
                            padding="same", activation='relu'))
    model.add(layers.Conv2D(32, (3, 3),
                            kernel_initializer=initializer,
                            kernel_regularizer=regularizer,
                            bias_regularizer=regularizer,
                            activity_regularizer=regularizer,
                            padding="same", activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3),
                            kernel_initializer=initializer,
                            kernel_regularizer=regularizer,
                            bias_regularizer=regularizer,
                            activity_regularizer=regularizer,
                            padding="same", activation='relu'))
    model.add(layers.Conv2D(64, (3, 3),
                            kernel_initializer=initializer,
                            kernel_regularizer=regularizer,
                            bias_regularizer=regularizer,
                            activity_regularizer=regularizer,
                            padding="same", activation='relu'))
    model.add(layers.Flatten())
    model.add(layers.Dense(64,
                           kernel_initializer=initializer,
                           kernel_regularizer=regularizer,
                           bias_regularizer=regularizer,
                           activity_regularizer=regularizer,
                           activation='relu'))
    model.add(layers.Dropout(.5))
    model.add(layers.Dense(10))

    model.build(input_shape=(None, 32,32,3))
    #model.summary()

    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=3e-4,
                                                                 decay_steps=100000,
                                                                 decay_rate=0.96)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])

    history =  model.fit(train_images, train_labels, epochs=40, batch_size=32,
                         validation_data=(test_images, test_labels),
                         #callbacks=[callback]
                         )

    plot_history(history)
    return model
# Out:
# Added cutout...

# %%
# to do: try between 3 and 8
model = train_coutout(3)
# Out:
# Cutout value: 3
# Epoch 1/40
# 1563/1563 [==============================] - 29s 18ms/step - loss: 2.0874 - accuracy: 0.3329 - val_loss: 1.5630 - val_accuracy: 0.5067
# Epoch 2/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.5522 - accuracy: 0.5060 - val_loss: 1.3111 - val_accuracy: 0.5920
# Epoch 3/40
# 1563/1563 [==============================] - 27s 18ms/step - loss: 1.3631 - accuracy: 0.5835 - val_loss: 1.1804 - val_accuracy: 0.6384
# Epoch 4/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.2469 - accuracy: 0.6284 - val_loss: 1.1241 - val_accuracy: 0.6715
# Epoch 5/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.1548 - accuracy: 0.6672 - val_loss: 1.0571 - val_accuracy: 0.6935
# Epoch 6/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.0922 - accuracy: 0.6891 - val_loss: 0.9921 - val_accuracy: 0.7182
# Epoch 7/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.0357 - accuracy: 0.7126 - val_loss: 0.9805 - val_accuracy: 0.7255
# Epoch 8/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.9938 - accuracy: 0.7288 - val_loss: 0.9566 - val_accuracy: 0.7350
# Epoch 9/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.9513 - accuracy: 0.7409 - val_loss: 0.9122 - val_accuracy: 0.7565
# Epoch 10/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.9122 - accuracy: 0.7588 - val_loss: 0.9213 - val_accuracy: 0.7518
# Epoch 11/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.8781 - accuracy: 0.7720 - val_loss: 0.8963 - val_accuracy: 0.7583
# Epoch 12/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.8488 - accuracy: 0.7808 - val_loss: 0.8850 - val_accuracy: 0.7650
# Epoch 13/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.8221 - accuracy: 0.7920 - val_loss: 0.8746 - val_accuracy: 0.7725
# Epoch 14/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.8007 - accuracy: 0.8002 - val_loss: 0.8580 - val_accuracy: 0.7779
# Epoch 15/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.7757 - accuracy: 0.8103 - val_loss: 0.9156 - val_accuracy: 0.7614
# Epoch 16/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.7539 - accuracy: 0.8171 - val_loss: 0.8440 - val_accuracy: 0.7845
# Epoch 17/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.7326 - accuracy: 0.8261 - val_loss: 0.8580 - val_accuracy: 0.7842
# Epoch 18/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.7200 - accuracy: 0.8326 - val_loss: 0.8523 - val_accuracy: 0.7887
# Epoch 19/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.7024 - accuracy: 0.8403 - val_loss: 0.8549 - val_accuracy: 0.7863
# Epoch 20/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.6756 - accuracy: 0.8498 - val_loss: 0.8787 - val_accuracy: 0.7861
# Epoch 21/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.6624 - accuracy: 0.8529 - val_loss: 0.8735 - val_accuracy: 0.7887
# Epoch 22/40
# 1563/1563 [==============================] - 29s 18ms/step - loss: 0.6527 - accuracy: 0.8590 - val_loss: 0.8387 - val_accuracy: 0.8021
# Epoch 23/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.6368 - accuracy: 0.8651 - val_loss: 0.8573 - val_accuracy: 0.7928
# Epoch 24/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.6217 - accuracy: 0.8696 - val_loss: 0.8633 - val_accuracy: 0.7913
# Epoch 25/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.6079 - accuracy: 0.8740 - val_loss: 0.8744 - val_accuracy: 0.7910
# Epoch 26/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5955 - accuracy: 0.8814 - val_loss: 0.8872 - val_accuracy: 0.7952
# Epoch 27/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5849 - accuracy: 0.8852 - val_loss: 0.8924 - val_accuracy: 0.7937
# Epoch 28/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5746 - accuracy: 0.8884 - val_loss: 0.8893 - val_accuracy: 0.7966
# Epoch 29/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5607 - accuracy: 0.8934 - val_loss: 0.8648 - val_accuracy: 0.8008
# Epoch 30/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.5548 - accuracy: 0.8975 - val_loss: 0.9038 - val_accuracy: 0.7952
# Epoch 31/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5404 - accuracy: 0.9012 - val_loss: 0.8878 - val_accuracy: 0.8016
# Epoch 32/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5352 - accuracy: 0.9038 - val_loss: 0.9554 - val_accuracy: 0.7849
# Epoch 33/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5259 - accuracy: 0.9077 - val_loss: 0.9232 - val_accuracy: 0.7970
# Epoch 34/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.5188 - accuracy: 0.9105 - val_loss: 0.9313 - val_accuracy: 0.7895
# Epoch 35/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5073 - accuracy: 0.9164 - val_loss: 0.9602 - val_accuracy: 0.7904
# Epoch 36/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5027 - accuracy: 0.9175 - val_loss: 0.9316 - val_accuracy: 0.7980
# Epoch 37/40
# 1563/1563 [==============================] - 29s 18ms/step - loss: 0.4958 - accuracy: 0.9193 - val_loss: 0.9649 - val_accuracy: 0.7959
# Epoch 38/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.4867 - accuracy: 0.9245 - val_loss: 0.9582 - val_accuracy: 0.7949
# Epoch 39/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.4811 - accuracy: 0.9269 - val_loss: 0.9781 - val_accuracy: 0.8000
# Epoch 40/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.4732 - accuracy: 0.9289 - val_loss: 0.9804 - val_accuracy: 0.7943

# %%
model = train_coutout(4)
# Out:
# Cutout value: 4
# Epoch 1/40
# 1563/1563 [==============================] - 29s 17ms/step - loss: 2.0681 - accuracy: 0.3535 - val_loss: 1.5426 - val_accuracy: 0.5071
# Epoch 2/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.5546 - accuracy: 0.5057 - val_loss: 1.3469 - val_accuracy: 0.5793
# Epoch 3/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.3664 - accuracy: 0.5843 - val_loss: 1.2192 - val_accuracy: 0.6321
# Epoch 4/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.2517 - accuracy: 0.6278 - val_loss: 1.1183 - val_accuracy: 0.6709
# Epoch 5/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.1609 - accuracy: 0.6650 - val_loss: 1.0865 - val_accuracy: 0.6841
# Epoch 6/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.0886 - accuracy: 0.6912 - val_loss: 1.0063 - val_accuracy: 0.7128
# Epoch 7/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.0319 - accuracy: 0.7126 - val_loss: 0.9779 - val_accuracy: 0.7225
# Epoch 8/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.9822 - accuracy: 0.7322 - val_loss: 0.9735 - val_accuracy: 0.7282
# Epoch 9/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.9436 - accuracy: 0.7478 - val_loss: 0.9529 - val_accuracy: 0.7372
# Epoch 10/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.9089 - accuracy: 0.7598 - val_loss: 0.9377 - val_accuracy: 0.7448
# Epoch 11/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8766 - accuracy: 0.7748 - val_loss: 0.9032 - val_accuracy: 0.7563
# Epoch 12/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8473 - accuracy: 0.7859 - val_loss: 0.8890 - val_accuracy: 0.7655
# Epoch 13/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.8238 - accuracy: 0.7926 - val_loss: 0.8781 - val_accuracy: 0.7668
# Epoch 14/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7963 - accuracy: 0.8046 - val_loss: 0.8521 - val_accuracy: 0.7800
# Epoch 15/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7796 - accuracy: 0.8094 - val_loss: 0.8797 - val_accuracy: 0.7727
# Epoch 16/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7580 - accuracy: 0.8195 - val_loss: 0.8839 - val_accuracy: 0.7722
# Epoch 17/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7346 - accuracy: 0.8285 - val_loss: 0.9384 - val_accuracy: 0.7597
# Epoch 18/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7161 - accuracy: 0.8342 - val_loss: 0.8476 - val_accuracy: 0.7822
# Epoch 19/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6973 - accuracy: 0.8420 - val_loss: 0.8358 - val_accuracy: 0.7909
# Epoch 20/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6805 - accuracy: 0.8476 - val_loss: 0.8697 - val_accuracy: 0.7852
# Epoch 21/40
# 1563/1563 [==============================] - 29s 18ms/step - loss: 0.6625 - accuracy: 0.8522 - val_loss: 0.8383 - val_accuracy: 0.7957
# Epoch 22/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6534 - accuracy: 0.8588 - val_loss: 0.8583 - val_accuracy: 0.7875
# Epoch 23/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6325 - accuracy: 0.8651 - val_loss: 0.8829 - val_accuracy: 0.7890
# Epoch 24/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6204 - accuracy: 0.8711 - val_loss: 0.8781 - val_accuracy: 0.7921
# Epoch 25/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6130 - accuracy: 0.8738 - val_loss: 0.8710 - val_accuracy: 0.7886
# Epoch 26/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5948 - accuracy: 0.8824 - val_loss: 0.8669 - val_accuracy: 0.7948
# Epoch 27/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5861 - accuracy: 0.8860 - val_loss: 0.8994 - val_accuracy: 0.7874
# Epoch 28/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5684 - accuracy: 0.8920 - val_loss: 0.9033 - val_accuracy: 0.7924
# Epoch 29/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5625 - accuracy: 0.8939 - val_loss: 0.9298 - val_accuracy: 0.7880
# Epoch 30/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5533 - accuracy: 0.8978 - val_loss: 0.9258 - val_accuracy: 0.7899
# Epoch 31/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5398 - accuracy: 0.9035 - val_loss: 0.8983 - val_accuracy: 0.7933
# Epoch 32/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5389 - accuracy: 0.9043 - val_loss: 0.9265 - val_accuracy: 0.7960
# Epoch 33/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5260 - accuracy: 0.9097 - val_loss: 0.9097 - val_accuracy: 0.7988
# Epoch 34/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5166 - accuracy: 0.9129 - val_loss: 0.9306 - val_accuracy: 0.7973
# Epoch 35/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5082 - accuracy: 0.9163 - val_loss: 0.9144 - val_accuracy: 0.7993
# Epoch 36/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5049 - accuracy: 0.9176 - val_loss: 0.9699 - val_accuracy: 0.7862
# Epoch 37/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.4976 - accuracy: 0.9205 - val_loss: 0.9602 - val_accuracy: 0.7973
# Epoch 38/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.4929 - accuracy: 0.9221 - val_loss: 0.9519 - val_accuracy: 0.8004
# Epoch 39/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.4832 - accuracy: 0.9236 - val_loss: 0.9556 - val_accuracy: 0.8001
# Epoch 40/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.4770 - accuracy: 0.9283 - val_loss: 1.0357 - val_accuracy: 0.7814

# %%
model = train_coutout(5)
# Out:
# Cutout value: 5
# Epoch 1/40
# 1563/1563 [==============================] - 29s 18ms/step - loss: 2.0859 - accuracy: 0.3451 - val_loss: 1.5491 - val_accuracy: 0.5042
# Epoch 2/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.5668 - accuracy: 0.4985 - val_loss: 1.4625 - val_accuracy: 0.5313
# Epoch 3/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.4017 - accuracy: 0.5705 - val_loss: 1.2960 - val_accuracy: 0.6018
# Epoch 4/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.2688 - accuracy: 0.6219 - val_loss: 1.1530 - val_accuracy: 0.6557
# Epoch 5/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.1726 - accuracy: 0.6578 - val_loss: 1.1023 - val_accuracy: 0.6781
# Epoch 6/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.1073 - accuracy: 0.6847 - val_loss: 1.0589 - val_accuracy: 0.6937
# Epoch 7/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.0486 - accuracy: 0.7072 - val_loss: 1.0446 - val_accuracy: 0.6953
# Epoch 8/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.0048 - accuracy: 0.7229 - val_loss: 0.9689 - val_accuracy: 0.7280
# Epoch 9/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.9616 - accuracy: 0.7391 - val_loss: 1.0071 - val_accuracy: 0.7200
# Epoch 10/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.9256 - accuracy: 0.7530 - val_loss: 0.9836 - val_accuracy: 0.7260
# Epoch 11/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8966 - accuracy: 0.7621 - val_loss: 0.9213 - val_accuracy: 0.7506
# Epoch 12/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8635 - accuracy: 0.7750 - val_loss: 0.9161 - val_accuracy: 0.7505
# Epoch 13/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8375 - accuracy: 0.7868 - val_loss: 0.9033 - val_accuracy: 0.7593
# Epoch 14/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8148 - accuracy: 0.7950 - val_loss: 0.8779 - val_accuracy: 0.7680
# Epoch 15/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7929 - accuracy: 0.8054 - val_loss: 0.8875 - val_accuracy: 0.7658
# Epoch 16/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.7704 - accuracy: 0.8124 - val_loss: 0.9055 - val_accuracy: 0.7641
# Epoch 17/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7530 - accuracy: 0.8176 - val_loss: 0.8560 - val_accuracy: 0.7786
# Epoch 18/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7301 - accuracy: 0.8270 - val_loss: 0.8643 - val_accuracy: 0.7802
# Epoch 19/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7177 - accuracy: 0.8322 - val_loss: 0.9057 - val_accuracy: 0.7718
# Epoch 20/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6936 - accuracy: 0.8405 - val_loss: 0.9190 - val_accuracy: 0.7674
# Epoch 21/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6800 - accuracy: 0.8468 - val_loss: 0.8866 - val_accuracy: 0.7836
# Epoch 22/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6619 - accuracy: 0.8534 - val_loss: 0.8726 - val_accuracy: 0.7833
# Epoch 23/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6493 - accuracy: 0.8593 - val_loss: 0.8906 - val_accuracy: 0.7872
# Epoch 24/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6381 - accuracy: 0.8639 - val_loss: 0.9087 - val_accuracy: 0.7817
# Epoch 25/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.6249 - accuracy: 0.8689 - val_loss: 0.8861 - val_accuracy: 0.7816
# Epoch 26/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6069 - accuracy: 0.8771 - val_loss: 0.8901 - val_accuracy: 0.7887
# Epoch 27/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5970 - accuracy: 0.8802 - val_loss: 0.8947 - val_accuracy: 0.7892
# Epoch 28/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5842 - accuracy: 0.8857 - val_loss: 0.8950 - val_accuracy: 0.7925
# Epoch 29/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5759 - accuracy: 0.8897 - val_loss: 0.8961 - val_accuracy: 0.7896
# Epoch 30/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5656 - accuracy: 0.8921 - val_loss: 0.9172 - val_accuracy: 0.7843
# Epoch 31/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5563 - accuracy: 0.8966 - val_loss: 0.9188 - val_accuracy: 0.7907
# Epoch 32/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5509 - accuracy: 0.8985 - val_loss: 0.9085 - val_accuracy: 0.7955
# Epoch 33/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5397 - accuracy: 0.9029 - val_loss: 0.9431 - val_accuracy: 0.7910
# Epoch 34/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.5298 - accuracy: 0.9069 - val_loss: 0.9470 - val_accuracy: 0.7878
# Epoch 35/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5211 - accuracy: 0.9117 - val_loss: 0.9764 - val_accuracy: 0.7869
# Epoch 36/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5135 - accuracy: 0.9124 - val_loss: 0.9444 - val_accuracy: 0.7892
# Epoch 37/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5077 - accuracy: 0.9164 - val_loss: 0.9835 - val_accuracy: 0.7857
# Epoch 38/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.4983 - accuracy: 0.9200 - val_loss: 0.9704 - val_accuracy: 0.7857
# Epoch 39/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.4989 - accuracy: 0.9191 - val_loss: 1.0012 - val_accuracy: 0.7861
# Epoch 40/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.4937 - accuracy: 0.9216 - val_loss: 0.9931 - val_accuracy: 0.7855

# %%
model = train_coutout(6)
# Out:
# Cutout value: 6
# Epoch 1/40
# 1563/1563 [==============================] - 28s 17ms/step - loss: 2.0813 - accuracy: 0.3578 - val_loss: 1.5623 - val_accuracy: 0.4984
# Epoch 2/40
# 1563/1563 [==============================] - 26s 16ms/step - loss: 1.5381 - accuracy: 0.5161 - val_loss: 1.3923 - val_accuracy: 0.5679
# Epoch 3/40
# 1563/1563 [==============================] - 27s 18ms/step - loss: 1.3776 - accuracy: 0.5819 - val_loss: 1.3513 - val_accuracy: 0.5766
# Epoch 4/40
# 1563/1563 [==============================] - 26s 16ms/step - loss: 1.2738 - accuracy: 0.6189 - val_loss: 1.2218 - val_accuracy: 0.6325
# Epoch 5/40
# 1563/1563 [==============================] - 26s 16ms/step - loss: 1.1955 - accuracy: 0.6498 - val_loss: 1.1746 - val_accuracy: 0.6520
# Epoch 6/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.1376 - accuracy: 0.6713 - val_loss: 1.1496 - val_accuracy: 0.6549
# Epoch 7/40
# 1563/1563 [==============================] - 26s 16ms/step - loss: 1.0915 - accuracy: 0.6891 - val_loss: 1.1012 - val_accuracy: 0.6790
# Epoch 8/40
# 1563/1563 [==============================] - 25s 16ms/step - loss: 1.0419 - accuracy: 0.7062 - val_loss: 1.0700 - val_accuracy: 0.6917
# Epoch 9/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.0042 - accuracy: 0.7227 - val_loss: 1.0638 - val_accuracy: 0.6969
# Epoch 10/40
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.9695 - accuracy: 0.7359 - val_loss: 1.0647 - val_accuracy: 0.6963
# Epoch 11/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.9369 - accuracy: 0.7489 - val_loss: 1.0416 - val_accuracy: 0.7063
# Epoch 12/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.9094 - accuracy: 0.7585 - val_loss: 1.0631 - val_accuracy: 0.6952
# Epoch 13/40
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.8872 - accuracy: 0.7663 - val_loss: 1.0065 - val_accuracy: 0.7245
# Epoch 14/40
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.8661 - accuracy: 0.7734 - val_loss: 1.0266 - val_accuracy: 0.7237
# Epoch 15/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8411 - accuracy: 0.7845 - val_loss: 1.0266 - val_accuracy: 0.7192
# Epoch 16/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8261 - accuracy: 0.7897 - val_loss: 1.0540 - val_accuracy: 0.7154
# Epoch 17/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7983 - accuracy: 0.8014 - val_loss: 1.0068 - val_accuracy: 0.7272
# Epoch 18/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7835 - accuracy: 0.8056 - val_loss: 0.9765 - val_accuracy: 0.7371
# Epoch 19/40
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.7683 - accuracy: 0.8133 - val_loss: 0.9856 - val_accuracy: 0.7366
# Epoch 20/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7494 - accuracy: 0.8212 - val_loss: 0.9926 - val_accuracy: 0.7435
# Epoch 21/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7413 - accuracy: 0.8251 - val_loss: 1.0255 - val_accuracy: 0.7330
# Epoch 22/40
# 1563/1563 [==============================] - 27s 18ms/step - loss: 0.7180 - accuracy: 0.8340 - val_loss: 0.9856 - val_accuracy: 0.7457
# Epoch 23/40
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.7097 - accuracy: 0.8370 - val_loss: 0.9927 - val_accuracy: 0.7484
# Epoch 24/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6925 - accuracy: 0.8438 - val_loss: 0.9982 - val_accuracy: 0.7464
# Epoch 25/40
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.6810 - accuracy: 0.8492 - val_loss: 1.0526 - val_accuracy: 0.7314
# Epoch 26/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6679 - accuracy: 0.8525 - val_loss: 0.9961 - val_accuracy: 0.7487
# Epoch 27/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6540 - accuracy: 0.8584 - val_loss: 1.0693 - val_accuracy: 0.7374
# Epoch 28/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.6385 - accuracy: 0.8654 - val_loss: 1.0519 - val_accuracy: 0.7464
# Epoch 29/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6353 - accuracy: 0.8668 - val_loss: 1.0723 - val_accuracy: 0.7425
# Epoch 30/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6232 - accuracy: 0.8718 - val_loss: 1.0709 - val_accuracy: 0.7416
# Epoch 31/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.6112 - accuracy: 0.8779 - val_loss: 1.0680 - val_accuracy: 0.7431
# Epoch 32/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6015 - accuracy: 0.8826 - val_loss: 1.0875 - val_accuracy: 0.7443
# Epoch 33/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5920 - accuracy: 0.8844 - val_loss: 1.1365 - val_accuracy: 0.7436
# Epoch 34/40
# 1563/1563 [==============================] - 27s 18ms/step - loss: 0.5833 - accuracy: 0.8877 - val_loss: 1.1017 - val_accuracy: 0.7460
# Epoch 35/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.5695 - accuracy: 0.8938 - val_loss: 1.1312 - val_accuracy: 0.7435
# Epoch 36/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5595 - accuracy: 0.8992 - val_loss: 1.1406 - val_accuracy: 0.7470
# Epoch 37/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5587 - accuracy: 0.8991 - val_loss: 1.0857 - val_accuracy: 0.7519
# Epoch 38/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5459 - accuracy: 0.9048 - val_loss: 1.1199 - val_accuracy: 0.7469
# Epoch 39/40
# 1563/1563 [==============================] - 27s 18ms/step - loss: 0.5367 - accuracy: 0.9078 - val_loss: 1.1877 - val_accuracy: 0.7475
# Epoch 40/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5283 - accuracy: 0.9122 - val_loss: 1.2087 - val_accuracy: 0.7403

# %%
model = train_coutout(7)
# Out:
# Cutout value: 7
# Epoch 1/40
# 1563/1563 [==============================] - 29s 17ms/step - loss: 2.2567 - accuracy: 0.3514 - val_loss: 1.6442 - val_accuracy: 0.4798
# Epoch 2/40
# 1563/1563 [==============================] - 27s 18ms/step - loss: 1.5892 - accuracy: 0.4995 - val_loss: 1.4895 - val_accuracy: 0.5367
# Epoch 3/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.4277 - accuracy: 0.5643 - val_loss: 1.3567 - val_accuracy: 0.5885
# Epoch 4/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.3138 - accuracy: 0.6076 - val_loss: 1.2809 - val_accuracy: 0.6125
# Epoch 5/40
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.2303 - accuracy: 0.6380 - val_loss: 1.2732 - val_accuracy: 0.6220
# Epoch 6/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.1556 - accuracy: 0.6681 - val_loss: 1.1671 - val_accuracy: 0.6648
# Epoch 7/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.1043 - accuracy: 0.6892 - val_loss: 1.1610 - val_accuracy: 0.6635
# Epoch 8/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.0590 - accuracy: 0.7077 - val_loss: 1.1346 - val_accuracy: 0.6703
# Epoch 9/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.0115 - accuracy: 0.7259 - val_loss: 1.1321 - val_accuracy: 0.6817
# Epoch 10/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.9747 - accuracy: 0.7396 - val_loss: 1.0795 - val_accuracy: 0.6942
# Epoch 11/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.9390 - accuracy: 0.7526 - val_loss: 1.0551 - val_accuracy: 0.7079
# Epoch 12/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.9083 - accuracy: 0.7645 - val_loss: 1.0864 - val_accuracy: 0.7034
# Epoch 13/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.8849 - accuracy: 0.7713 - val_loss: 1.0749 - val_accuracy: 0.7128
# Epoch 14/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8616 - accuracy: 0.7816 - val_loss: 1.0239 - val_accuracy: 0.7227
# Epoch 15/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.8349 - accuracy: 0.7914 - val_loss: 0.9904 - val_accuracy: 0.7338
# Epoch 16/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.8148 - accuracy: 0.8022 - val_loss: 1.0102 - val_accuracy: 0.7335
# Epoch 17/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.7917 - accuracy: 0.8089 - val_loss: 1.0161 - val_accuracy: 0.7323
# Epoch 18/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.7730 - accuracy: 0.8161 - val_loss: 0.9929 - val_accuracy: 0.7374
# Epoch 19/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.7609 - accuracy: 0.8230 - val_loss: 1.0308 - val_accuracy: 0.7301
# Epoch 20/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.7405 - accuracy: 0.8284 - val_loss: 1.0069 - val_accuracy: 0.7351
# Epoch 21/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7238 - accuracy: 0.8321 - val_loss: 1.0976 - val_accuracy: 0.7196
# Epoch 22/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7113 - accuracy: 0.8392 - val_loss: 1.0221 - val_accuracy: 0.7385
# Epoch 23/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6939 - accuracy: 0.8466 - val_loss: 1.0244 - val_accuracy: 0.7423
# Epoch 24/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6814 - accuracy: 0.8503 - val_loss: 1.0192 - val_accuracy: 0.7408
# Epoch 25/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6694 - accuracy: 0.8561 - val_loss: 1.0227 - val_accuracy: 0.7469
# Epoch 26/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.6486 - accuracy: 0.8636 - val_loss: 1.0234 - val_accuracy: 0.7541
# Epoch 27/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6396 - accuracy: 0.8657 - val_loss: 1.1260 - val_accuracy: 0.7293
# Epoch 28/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6289 - accuracy: 0.8718 - val_loss: 1.0223 - val_accuracy: 0.7465
# Epoch 29/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.6133 - accuracy: 0.8770 - val_loss: 1.0696 - val_accuracy: 0.7468
# Epoch 30/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6066 - accuracy: 0.8796 - val_loss: 1.0293 - val_accuracy: 0.7512
# Epoch 31/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6000 - accuracy: 0.8830 - val_loss: 1.0339 - val_accuracy: 0.7514
# Epoch 32/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5875 - accuracy: 0.8884 - val_loss: 1.0915 - val_accuracy: 0.7418
# Epoch 33/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5757 - accuracy: 0.8925 - val_loss: 1.0941 - val_accuracy: 0.7481
# Epoch 34/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5692 - accuracy: 0.8961 - val_loss: 1.1039 - val_accuracy: 0.7489
# Epoch 35/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5609 - accuracy: 0.8993 - val_loss: 1.1069 - val_accuracy: 0.7412
# Epoch 36/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5580 - accuracy: 0.9002 - val_loss: 1.1241 - val_accuracy: 0.7506
# Epoch 37/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5430 - accuracy: 0.9057 - val_loss: 1.1258 - val_accuracy: 0.7457
# Epoch 38/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5322 - accuracy: 0.9108 - val_loss: 1.1388 - val_accuracy: 0.7470
# Epoch 39/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.5287 - accuracy: 0.9116 - val_loss: 1.1448 - val_accuracy: 0.7475
# Epoch 40/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5196 - accuracy: 0.9167 - val_loss: 1.1508 - val_accuracy: 0.7493

# %%
model = train_coutout(8)
# Out:
# Cutout value: 8
# Epoch 1/40
# 1563/1563 [==============================] - 28s 17ms/step - loss: 2.0416 - accuracy: 0.3402 - val_loss: 1.7477 - val_accuracy: 0.4395
# Epoch 2/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.6163 - accuracy: 0.4895 - val_loss: 1.6159 - val_accuracy: 0.4911
# Epoch 3/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.4743 - accuracy: 0.5420 - val_loss: 1.5280 - val_accuracy: 0.5244
# Epoch 4/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.3761 - accuracy: 0.5810 - val_loss: 1.4367 - val_accuracy: 0.5592
# Epoch 5/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.3055 - accuracy: 0.6065 - val_loss: 1.4048 - val_accuracy: 0.5710
# Epoch 6/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.2448 - accuracy: 0.6310 - val_loss: 1.3665 - val_accuracy: 0.5834
# Epoch 7/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.1864 - accuracy: 0.6512 - val_loss: 1.3556 - val_accuracy: 0.5943
# Epoch 8/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.1515 - accuracy: 0.6665 - val_loss: 1.3515 - val_accuracy: 0.5960
# Epoch 9/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.1133 - accuracy: 0.6792 - val_loss: 1.2820 - val_accuracy: 0.6217
# Epoch 10/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.0834 - accuracy: 0.6918 - val_loss: 1.2856 - val_accuracy: 0.6190
# Epoch 11/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.0476 - accuracy: 0.7074 - val_loss: 1.2834 - val_accuracy: 0.6234
# Epoch 12/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.0175 - accuracy: 0.7182 - val_loss: 1.2408 - val_accuracy: 0.6397
# Epoch 13/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.9928 - accuracy: 0.7274 - val_loss: 1.2827 - val_accuracy: 0.6282
# Epoch 14/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.9662 - accuracy: 0.7382 - val_loss: 1.2667 - val_accuracy: 0.6372
# Epoch 15/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.9456 - accuracy: 0.7446 - val_loss: 1.2494 - val_accuracy: 0.6420
# Epoch 16/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.9230 - accuracy: 0.7547 - val_loss: 1.2822 - val_accuracy: 0.6404
# Epoch 17/40
# 1563/1563 [==============================] - 30s 19ms/step - loss: 0.9051 - accuracy: 0.7612 - val_loss: 1.2985 - val_accuracy: 0.6381
# Epoch 18/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8914 - accuracy: 0.7678 - val_loss: 1.2747 - val_accuracy: 0.6468
# Epoch 19/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8724 - accuracy: 0.7746 - val_loss: 1.2801 - val_accuracy: 0.6507
# Epoch 20/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.8530 - accuracy: 0.7823 - val_loss: 1.2589 - val_accuracy: 0.6512
# Epoch 21/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8362 - accuracy: 0.7898 - val_loss: 1.2905 - val_accuracy: 0.6475
# Epoch 22/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8245 - accuracy: 0.7958 - val_loss: 1.2703 - val_accuracy: 0.6559
# Epoch 23/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8086 - accuracy: 0.8015 - val_loss: 1.2956 - val_accuracy: 0.6454
# Epoch 24/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7903 - accuracy: 0.8091 - val_loss: 1.3982 - val_accuracy: 0.6329
# Epoch 25/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7790 - accuracy: 0.8128 - val_loss: 1.3199 - val_accuracy: 0.6474
# Epoch 26/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7658 - accuracy: 0.8187 - val_loss: 1.3261 - val_accuracy: 0.6454
# Epoch 27/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7549 - accuracy: 0.8236 - val_loss: 1.3688 - val_accuracy: 0.6391
# Epoch 28/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7376 - accuracy: 0.8312 - val_loss: 1.3601 - val_accuracy: 0.6503
# Epoch 29/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7276 - accuracy: 0.8341 - val_loss: 1.3332 - val_accuracy: 0.6491
# Epoch 30/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.7166 - accuracy: 0.8395 - val_loss: 1.4222 - val_accuracy: 0.6440
# Epoch 31/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.7048 - accuracy: 0.8449 - val_loss: 1.3726 - val_accuracy: 0.6512
# Epoch 32/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6911 - accuracy: 0.8502 - val_loss: 1.3630 - val_accuracy: 0.6548
# Epoch 33/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6792 - accuracy: 0.8555 - val_loss: 1.4244 - val_accuracy: 0.6433
# Epoch 34/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.6724 - accuracy: 0.8582 - val_loss: 1.4309 - val_accuracy: 0.6526
# Epoch 35/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6633 - accuracy: 0.8602 - val_loss: 1.4133 - val_accuracy: 0.6553
# Epoch 36/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6536 - accuracy: 0.8686 - val_loss: 1.4011 - val_accuracy: 0.6552
# Epoch 37/40
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.6417 - accuracy: 0.8715 - val_loss: 1.4969 - val_accuracy: 0.6424
# Epoch 38/40
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.6294 - accuracy: 0.8756 - val_loss: 1.4978 - val_accuracy: 0.6483
# Epoch 39/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6244 - accuracy: 0.8779 - val_loss: 1.5099 - val_accuracy: 0.6546
# Epoch 40/40
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6167 - accuracy: 0.8828 - val_loss: 1.5364 - val_accuracy: 0.6461

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

model.save(f"./weights_v2/test_acc_{str(test_acc)[:5]}_with_cutout3_v3")
# Out:
# 313/313 - 1s - loss: 1.5364 - accuracy: 0.6461 - 1s/epoch - 5ms/step
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.

# %%
print("More train")

history =  model.fit(train_images, train_labels, epochs=15, batch_size=256,
                     validation_data=(test_images, test_labels),
                     #callbacks=[callback]
                     )

plot_history(history)
# Out:
# More train
# Epoch 1/15
# 196/196 [==============================] - 20s 102ms/step - loss: 0.5219 - accuracy: 0.9202 - val_loss: 1.5801 - val_accuracy: 0.6538
# Epoch 2/15
# 196/196 [==============================] - 18s 94ms/step - loss: 0.4959 - accuracy: 0.9305 - val_loss: 1.5904 - val_accuracy: 0.6586
# Epoch 3/15
# 196/196 [==============================] - 18s 93ms/step - loss: 0.4828 - accuracy: 0.9348 - val_loss: 1.6167 - val_accuracy: 0.6524
# Epoch 4/15
# 196/196 [==============================] - 18s 92ms/step - loss: 0.4796 - accuracy: 0.9361 - val_loss: 1.6162 - val_accuracy: 0.6522
# Epoch 5/15
# 196/196 [==============================] - 19s 97ms/step - loss: 0.4733 - accuracy: 0.9370 - val_loss: 1.6169 - val_accuracy: 0.6569
# Epoch 6/15
# 196/196 [==============================] - 20s 100ms/step - loss: 0.4686 - accuracy: 0.9409 - val_loss: 1.6410 - val_accuracy: 0.6535
# Epoch 7/15
# 196/196 [==============================] - 19s 97ms/step - loss: 0.4639 - accuracy: 0.9420 - val_loss: 1.6495 - val_accuracy: 0.6531
# Epoch 8/15
# 196/196 [==============================] - 18s 93ms/step - loss: 0.4600 - accuracy: 0.9425 - val_loss: 1.6827 - val_accuracy: 0.6457
# Epoch 9/15
# 196/196 [==============================] - 18s 93ms/step - loss: 0.4580 - accuracy: 0.9428 - val_loss: 1.6580 - val_accuracy: 0.6528
# Epoch 10/15
# 196/196 [==============================] - 18s 92ms/step - loss: 0.4546 - accuracy: 0.9441 - val_loss: 1.6878 - val_accuracy: 0.6449
# Epoch 11/15
# 196/196 [==============================] - 21s 106ms/step - loss: 0.4524 - accuracy: 0.9450 - val_loss: 1.6432 - val_accuracy: 0.6534
# Epoch 12/15
# 196/196 [==============================] - 19s 98ms/step - loss: 0.4461 - accuracy: 0.9470 - val_loss: 1.6856 - val_accuracy: 0.6500
# Epoch 13/15
# 196/196 [==============================] - 19s 97ms/step - loss: 0.4457 - accuracy: 0.9478 - val_loss: 1.6663 - val_accuracy: 0.6521
# Epoch 14/15
# 196/196 [==============================] - 19s 97ms/step - loss: 0.4424 - accuracy: 0.9483 - val_loss: 1.6712 - val_accuracy: 0.6470
# Epoch 15/15
# 196/196 [==============================] - 20s 104ms/step - loss: 0.4405 - accuracy: 0.9490 - val_loss: 1.6800 - val_accuracy: 0.6471

# %%
new_model = tf.keras.models.load_model('/content/drive/MyDrive/weights/test_acc_0.74_with_he_initializer')

# Check its architecture
new_model.summary()

new_model.compile(optimizer='adam',
             loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             metrics=['accuracy'])

test_loss, test_acc = new_model.evaluate(test_images,  test_labels, verbose=2)
print(test_acc, test_loss)
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# Model: "sequential_147"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_443 (Conv2D)         (None, 32, 32, 32)        896
#
#  conv2d_444 (Conv2D)         (None, 32, 32, 32)        9248
#
#  max_pooling2d_274 (MaxPooli  (None, 16, 16, 32)       0
#  ng2D)
#
#  conv2d_445 (Conv2D)         (None, 16, 16, 32)        9248
#
#  conv2d_446 (Conv2D)         (None, 16, 16, 32)        9248
#
#  max_pooling2d_275 (MaxPooli  (None, 8, 8, 32)         0
#  ng2D)
#
#  conv2d_447 (Conv2D)         (None, 8, 8, 64)          18496
#
#  conv2d_448 (Conv2D)         (None, 8, 8, 64)          36928
#
#  flatten_135 (Flatten)       (None, 4096)              0
#
#  dense_270 (Dense)           (None, 64)                262208
#
#  dense_271 (Dense)           (None, 10)                650
#
# =================================================================
# Total params: 346,922
# Trainable params: 346,922
# Non-trainable params: 0
# _________________________________________________________________
# 313/313 - 1s - loss: 0.9883 - accuracy: 0.7409 - 1s/epoch - 4ms/step
# 0.7408999800682068 0.9883367419242859

# %% [markdown]
# This was pretty easy!  In the next laboratory we'll look at a basic "recipe" on how we can effectively tune the hyperparameters of a network, but for now let's just get familiar with _tensorflow_ and see how we can modify some parameters of this vanilla network.
#
# - First of all, move the model.summary() call at the end of your model creation (after the last dense layer) and analyse the number of parameters of each layer.
# - [Serialize](https://www.tensorflow.org/guide/keras/save_and_serialize) your model after training.
# - Change the initializers of the layers with ReLu activations to [He initializer](https://www.tensorflow.org/api_docs/python/tf/keras/initializers/HeNormal). Retrain and save the results.
# - Add some [regularization](https://keras.io/api/layers/regularizers/) to your network. Retrain and save the results.
# - Add a [dropout layer](https://keras.io/api/layers/regularization_layers/dropout/) after the layer with the highest number of parameters and retrain your network. Retrain and save the results.
#
# Plot the learning curver for all teh training that you performed.
# Create a table to compare the accuracy of your trained models.
#
# | Colum1      | Column2 |
# | ----------- | ----------- |
# | Cell11      | Cell12      |
# | Cell21      | Cell22      |

# %% [markdown]
# ## Writing a custom layer
#
# As you observed, when using _tensorflow_ you work at a high level of abstraction via layers. In other words, you don't need to get your hands dirty by manipulating variables, and usually you just stack several layers on top of each other to build your models.
#
# _tensorflow_ provides by default many layers commonly used in machine learning, but it also provides you an easy way to write your custom layers based on your needs. These layers can be written  from scratch or as the composition of several existing layers.
#
# To implement a custom layer you just need to extend from _tf.keras.Layer_ and implement the following methods:
# - \_\_init__(), where you can do all input-independent initialization;
# - build(), where you know the shapes of the input tensors and can do the rest of the initialization; you can as well create all the variables in the constructor, but  the advantage of creating them in build is that it enables late variable creation based on the shape of the inputs the layer will operate on;
# - call(), where you do the forward computation of that layer
#
# In the last part of the laboratory you will implement a custom image augmentation layer, namely [_cutout_](https://arxiv.org/pdf/1708.04552.pdf).
#
# Cutout is a very simple augmentation that can boost your test accuracy with more than 1%.
#
# "_Cutout is a simple regularization technique for convolutional neural networks that involves removing contiguous
# sections of input images, effectively augmenting the dataset
# with partially occluded versions of existing samples. This
# technique can be interpreted as an extension of dropout in
# input space, but with a spatial prior applied, much in the
# same way that CNNs apply a spatial prior to achieve improved performance over feed-forward networks on image
# data._"
#
# ## Implementation details (text from the original cutout paper)
# "_To implement cutout, we simply apply a fixed-size zeromask to a random location of each input image during each
# epoch of training._
#
# <img src="https://raw.githubusercontent.com/xkumiyu/numpy-data-augmentation/master/data/output/cutout.jpg" width=200px/>
#
# _When cutout is applied to an image, we randomly select a pixel coordinate within the image
# as a center point and then place the cutout mask around that
# location.
# This method allows for the possibility that not all
# parts of the cutout mask are contained within the image. Interestingly, we found that allowing portions of the patches
# to lay outside the borders of the image (rather than constraining the entire patch to be within the image) was critical to achieving good performance._"
#
# You can follow [this](https://www.tensorflow.org/tutorials/images/data_augmentation#custom_data_augmentation) tutorial to see how you can write a custom data augmentation layer.
